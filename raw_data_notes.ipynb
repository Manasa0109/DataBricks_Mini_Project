# %%
bronze_path = "/Volumes/data_architects/bronze_layer/raw_data_volume/"


df_aisles = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/default/sample_data/aisles.csv")

df_departments = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/default/sample_data/departments.csv")

df_orders = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/default/sample_data/orders.csv")

df_products = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/default/sample_data/products.csv")

df_order_products = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/default/sample_data/order_products__train.csv")

# %%
df_aisles.write.format("delta") \
    .mode("overwrite") \
    .save(bronze_path + "aisles")

df_departments.write.format("delta") \
    .mode("overwrite") \
    .save(bronze_path + "departments")

df_orders.write.format("delta") \
    .mode("overwrite") \
    .save(bronze_path + "orders")

df_products.write.format("delta") \
    .mode("overwrite") \
    .save(bronze_path + "products")

df_order_products.write.format("delta") \
    .mode("overwrite") \
    .save(bronze_path + "order_products")

# %%
spark.read.format("delta").load(bronze_path + "orders").display()
spark.read.format("delta").load(bronze_path + "products").display()
spark.read.format("delta").load(bronze_path + "order_products").display()

# %%
df_aisles.count()

# %%
df_departments.count()

# %%
df_orders.count()

# %%
df_products.count()

# %%
df_order_products.count()
